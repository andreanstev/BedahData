# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
df = pd.read_csv('GlobalTemperatures.csv')

# %%
df = df.iloc[1200:]

# %%
df
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
df['dt'] = pd.to_datetime(df['dt'], format='%Y-%m-%d')

# %%
df[['dt','LandAverageTemperature']].plot(kind='line',figsize = (20,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ...

# %%
ax = plt.figure(figsize=(20,10))
plt.plot(df['dt'],df['LandAverageTemperature'])

# %%
df.tail()
# Out:
#              dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3187 2015-08-01                  14.755                              0.072
# 3188 2015-09-01                  12.999                              0.079
# 3189 2015-10-01                  10.801                              0.102
# 3190 2015-11-01                   7.433                              0.119
# 3191 2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 3187              20.699                          0.110               9.005
# 3188              18.845                          0.088               7.199
# 3189              16.450                          0.059               5.232
# 3190              12.892                          0.093               2.157
# 3191              10.725                          0.154               0.287
#
# ...

# %%
df_country = pd.read_csv('GlobalLandTemperaturesByCountry.csv')

# %%
df_country.dropna(axis = 0).groupby('Country').mean().sort_values('AverageTemperature').plot(kind = 'barh',y = 'AverageTemperature', figsize = (10,30))

# %%
dfhappiness2015 = pd.read_csv('2015.csv')
dfhappiness2016 = pd.read_csv('2016.csv')
dfhappiness2017 = pd.read_csv('2017.csv')
dfhappiness2018 = pd.read_csv('2018.csv')
dfhappiness2019 = pd.read_csv('2019.csv')
dfhappiness2020 = pd.read_csv('2020.csv')

# %%
dfhappiness2015.isnull().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Standard Error                   False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                False
# dtype: bool

# %%
dfhappiness2016.isnull().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Lower Confidence Interval        False
# Upper Confidence Interval        False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                False
# dtype: bool

# %%
dfhappiness2017.isnull().any()
# Out:
# Country                          False
# Happiness.Rank                   False
# Happiness.Score                  False
# Whisker.high                     False
# Whisker.low                      False
# Economy..GDP.per.Capita.         False
# Family                           False
# Health..Life.Expectancy.         False
# Freedom                          False
# Generosity                       False
# Trust..Government.Corruption.    False
# Dystopia.Residual                False
# dtype: bool

# %%
dfhappiness2018.isnull().any()
# Out:
# Overall rank                    False
# Country or region               False
# Score                           False
# GDP per capita                  False
# Social support                  False
# Healthy life expectancy         False
# Freedom to make life choices    False
# Generosity                      False
# Perceptions of corruption        True
# dtype: bool

# %%
dfhappiness2019.isnull().any()
# Out:
# Overall rank                    False
# Country or region               False
# Score                           False
# GDP per capita                  False
# Social support                  False
# Healthy life expectancy         False
# Freedom to make life choices    False
# Generosity                      False
# Perceptions of corruption       False
# dtype: bool

# %%
dfhappiness2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
dfhappiness2020.plot(kind = 'barh', x='Country name', y = 'Ladder score', figsize= (10,30))

# %%
dfhappiness2020.plot(kind = 'barh', x='Country name', y = 'Explained by: Log GDP per capita', figsize= (10,30))

# %%
dfhappiness2020.plot(kind = 'barh', x='Country name', y = 'Healthy life expectancy', figsize= (10,30))

# %%
dfhappiness2020.plot(kind = 'barh', x='Country name', y = 'Explained by: Generosity', figsize= (10,30))

# %%
dfhappiness2020.plot(kind = 'barh', x='Country name', y = 'Explained by: Perceptions of corruption', figsize= (10,30))

# %%
dfhappiness2020_1 = dfhappiness2020.set_index('Country name')
dfhappiness2020_1
# Out:
#                           Regional indicator  Ladder score  \
# Country name
# Finland                       Western Europe        7.8087
# Denmark                       Western Europe        7.6456
# Switzerland                   Western Europe        7.5599
# Iceland                       Western Europe        7.5045
# Norway                        Western Europe        7.4880
# ...                                      ...           ...
# Central African Republic  Sub-Saharan Africa        3.4759
# Rwanda                    Sub-Saharan Africa        3.3123
# Zimbabwe                  Sub-Saharan Africa        3.2992
# South Sudan               Sub-Saharan Africa        2.8166
# Afghanistan                       South Asia        2.5669
#
#                           Standard error of ladder score  upperwhisker  \
# Country name
# Finland                                         0.031156      7.869766
# Denmark                                         0.033492      7.711245
# ...

# %%
dfeducation = pd.read_csv('educationrankbycountry.csv') #65 Negara Teratas di Edukasi

# %%
dfeducation = dfeducation.set_index('country')

# %%
dfeducation[totalScore]
# Out:
#              totalScore  readingScore  mathScore  scienceScore
# country
# China              1731           556        600           575
# Hong Kong          1637           533        555           549
# Finland            1631           536        541           554
# Singapore          1630           526        562           542
# South Korea        1623           539        546           538
# ...                 ...           ...        ...           ...
# Albania            1153           385        377           391
# Qatar              1119           372        368           379
# Panama             1107           371        360           376
# Peru               1104           370        365           369
# Kyrgyzstan          975           314        331           330
#
# [65 rows x 4 columns]

# %%
#dfhappiness2020_2 = dataset happiness index yang sudah digabungkan dengan education score
dfhappiness2020_2 = pd.concat([dfhappiness2020_1,dfeducation], axis = 1)

# %%
null_index = dfhappiness2020_2[dfhappiness2020_2['Regional indicator'].isnull() == True].index

# %%
dfhappiness2020_2.drop(null_index, axis = 0, inplace = True) #Negara yang tidak masuk ke education ranking (null) diisi nol

# %%
dfhappiness2020_2.fillna(0, inplace = True)

# %%
dfhappiness2020_2.drop(['readingScore','mathScore','scienceScore','upperwhisker','lowerwhisker'], axis = 1, inplace=True)

# %%
dfhappiness2020_2.rename(columns={'totalScore':'educationScore'},inplace=True)

# %%
dfhappiness2020_2.head()
# Out:
#             Regional indicator  Ladder score  Standard error of ladder score  \
# Finland         Western Europe        7.8087                        0.031156
# Denmark         Western Europe        7.6456                        0.033492
# Switzerland     Western Europe        7.5599                        0.035014
# Iceland         Western Europe        7.5045                        0.059616
# Norway          Western Europe        7.4880                        0.034837
#
#              Logged GDP per capita  Social support  Healthy life expectancy  \
# Finland                  10.639267        0.954330                71.900825
# Denmark                  10.774001        0.955991                72.402504
# Switzerland              10.979933        0.942847                74.102448
# Iceland                  10.772559        0.974670                73.000000
# Norway                   11.087804        0.952487                73.200783
#
# ...

# %%
dfhappiness2020_2['scaled_educationScore'] = (dfhappiness2020_2['educationScore']-dfhappiness2020_2['educationScore'].min())/(dfhappiness2020_2['educationScore'].max()-dfhappiness2020_2['educationScore'].min())

# %%
dfhappiness2020_2.head()
# Out:
#             Regional indicator  Ladder score  Standard error of ladder score  \
# Finland         Western Europe        7.8087                        0.031156
# Denmark         Western Europe        7.6456                        0.033492
# Switzerland     Western Europe        7.5599                        0.035014
# Iceland         Western Europe        7.5045                        0.059616
# Norway          Western Europe        7.4880                        0.034837
#
#              Logged GDP per capita  Social support  Healthy life expectancy  \
# Finland                  10.639267        0.954330                71.900825
# Denmark                  10.774001        0.955991                72.402504
# Switzerland              10.979933        0.942847                74.102448
# Iceland                  10.772559        0.974670                73.000000
# Norway                   11.087804        0.952487                73.200783
#
# ...

# %%
dfhappiness2020_2.plot(kind = 'barh', y = 'scaled_educationScore', figsize= (10,30))

# %%
sns.heatmap(dfhappiness2020_2.corr())

# %%
sns.lmplot(x= 'Ladder score', y='Perceptions of corruption', data = dfhappiness2020_2,order=2) #Polynomial regression plot

# %%
#dfhappiness2020_3 = dataset happiness index berisi 60 negara yang memiliki education score
dfhappiness2020_3 = dfhappiness2020_2.drop(dfhappiness2020_2[dfhappiness2020_2['educationScore']==0].index, axis=0)

# %%
sns.lmplot(x= 'Ladder score', y='educationScore', data = dfhappiness2020_3)

# %%
dfhappiness2020_3[dfhappiness2020_3['Ladder score']>6.5]
# Out:
#                                 Regional indicator  Ladder score  \
# Finland                             Western Europe        7.8087
# Denmark                             Western Europe        7.6456
# Switzerland                         Western Europe        7.5599
# Iceland                             Western Europe        7.5045
# Norway                              Western Europe        7.4880
# Netherlands                         Western Europe        7.4489
# Sweden                              Western Europe        7.3535
# New Zealand                  North America and ANZ        7.2996
# Austria                             Western Europe        7.2942
# Luxembourg                          Western Europe        7.2375
# Canada                       North America and ANZ        7.2321
# Australia                    North America and ANZ        7.2228
# United Kingdom                      Western Europe        7.1645
# ...

# %%
dfhappiness2020_3[dfhappiness2020_3['Ladder score']>6.5]['Regional indicator'].value_counts()
# Out:
# Western Europe                  14
# North America and ANZ            4
# Middle East and North Africa     2
# Central and Eastern Europe       1
# Name: Regional indicator, dtype: int64

# %%
sns.heatmap(dfhappiness2020_3[dfhappiness2020_3['Ladder score']>6.5].corr())

# %%
dfhappiness2020_2.groupby('Regional indicator').mean().plot(kind='barh',y='Ladder score')
